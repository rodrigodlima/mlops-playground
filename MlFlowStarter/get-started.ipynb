# %% [markdown]
# # MlFlow Tracking Server

# %% [markdown]
# Start the MLflow server:
#
# $ mlflow ui

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5001")

# %%
mlflow.set_experiment("Check localhost connection")

with mlflow.start_run():
    mlflow.log_metric("test", 1)
    mlflow.log_metric("Name", 2)
# Out:
# 2026/05/20 08:42:39 INFO mlflow.tracking.fluent: Experiment with name 'Check localhost connection' does not exist. Creating a new experiment.
# 🏃 View run casual-mole-523 at: http://127.0.0.1:5000/#/experiments/1/runs/5c7b6e0694af4456a3b1b559ad788c66
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
